# %% [markdown]
# ##  주택청약 FAQ 시스템 챗봇 구현 - 문서 전처리 + RAG + Gradio ChatInterface
#
# ### 학습 목표
#
# 1. 텍스트 문서를 로드하고 구조화된 Q&A 쌍으로 파싱
# 2. LLM을 활용한 키워드 추출 및 요약 생성
# 3. Chroma 벡터 데이터베이스에 문서 임베딩 저장
# 4. MMR 검색 및 메타데이터 필터링 구현
# 5. RAG 체인 구성 및 문서 관련성 평가
# 6. Gradio를 사용한 대화형 챗봇 인터페이스 구현
#
# ---

# %% [markdown]
# ### 사전 준비
#
# **1. 환경 변수 설정**
#
# `.env` 파일에 다음 내용을 추가하세요:
# ```
# OPENAI_API_KEY=your-api-key-here
# ```
#
# **2. 필수 패키지 설치**
# ```bash
# pip install langchain-openai langchain-community langchain-core
# pip install langchain-chroma chromadb
# pip install python-dotenv gradio
# ```
#
# **3. 데이터 파일**
# - `data/housing_faq.txt` 파일 필요 (국토교통부 주택청약 FAQ 50개 Q&A)

# %% [markdown]
# # 환경 설정 및 준비

# %% [markdown]
# `(1) Env 환경변수`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# `(2) 기본 라이브러리`

# %%
import os
from glob import glob

from pprint import pprint
import json

# %% [markdown]
# `(3) LLM 설정`

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model='gpt-4.1-mini',      # 사용할 모델
    temperature=0.1,            # 낮은 값: 일관된 답변 (0.0~2.0)
    top_p=0.9,                  # 토큰 샘플링 확률 임계값 (0.0~1.0)
)

# %% [markdown]
# # **문서 전처리 파이프라인**
#
# * 문서 전처리의 첫 단계는 데이터 정제로, 원본 문서에서 불필요한 요소(HTML 태그, 특수문자, 중복 내용 등)를 제거하고 텍스트를 표준화하는 과정입니다. 이는 검색 품질과 직결되는 중요한 단계입니다.
#
# * 문서 청킹(Chunking)은 긴 문서를 의미 있는 작은 단위로 분할하는 과정으로, 문장 단위나 단락 단위로 나누되 문맥의 연속성을 유지하는 것이 핵심입니다. 이는 검색 정확도와 답변 생성의 품질에 직접적인 영향을 미칩니다.
#
# * 임베딩(Embedding) 생성은 텍스트를 고차원의 벡터로 변환하는 과정으로, 문서의 의미적 특성을 수치화하여 효율적인 검색을 가능하게 합니다. 이때 사용되는 임베딩 모델의 선택이 검색 성능을 좌우하는 중요한 요소가 됩니다.
#
# * 마지막으로 벡터 데이터베이스 색인화 단계에서는 생성된 임베딩을 효율적으로 저장하고 검색할 수 있는 구조로 변환합니다. 이는 대규모 문서 집합에서도 빠른 검색을 가능하게 하는 핵심 요소입니다.

# %% [markdown]
# ### 1) 문서 로드
#
# - 국토교통부 주택청약 FAQ에서 일부 내용(청약자격, 청약통장)을 발췌하여 재가공
# - Q1 ~ Q50까지 모두 50개의 문답이 포함된 텍스트 파일

# %%
# 파일 경로 설정
faq_text_file = "data/housing_faq.txt"

# 파일 읽기 - 파이썬 내장 함수 사용 (encoding='utf-8' 추가)
with open(faq_text_file, 'r', encoding='utf-8') as f:
    faq_text = f.read()

# 파일 내용 확인
print(faq_text[:500])
# Out:
# Q1 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# A 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다.
# 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# Q2 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# A 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다.
# * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원
# 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의

# %% [markdown]
# ##### ***[실습] TextLoader를 사용하여, 텍스트 문서를 로드합니다.***

# %%
# 여기에 코드를 작성하세요.

# %%
from langchain_community.document_loaders import TextLoader

# TODO: TextLoader 클래스를 사용하여 FAQ 텍스트 파일을 로드
loader = TextLoader(faq_text_file, encoding='utf-8')
docs = loader.load()
len(docs)
# Out:
# 1

# %%
# 문서 확인
print(docs[0].page_content[:500])
# Out:
# Q1 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# A 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다.
# 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# Q2 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# A 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다.
# * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원
# 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의

# %%
# 문서 메타데이터 확인
docs[0].metadata
# Out:
# {'source': 'data/housing_faq.txt'}

# %% [markdown]
# ### 2) 문서 전처리

# %% [markdown]
# `(1) 각 질문과 답변을 쌍으로 추출하여 정리 (정규표현식 활용)`

# %%
import re

def extract_qa_pairs(text):
    qa_pairs = []
    
    # 텍스트를 라인별로 분리하고 각 라인의 앞뒤 공백 제거
    lines = [line.strip() for line in text.split('\n')]
    current_question = None
    current_answer = []
    current_number = None
    in_answer = False
    
    for i, line in enumerate(lines):
        if not line:  # 빈 라인 처리
            if in_answer and current_answer and i + 1 < len(lines) and lines[i + 1].startswith('Q'):
                # 다음 질문이 시작되기 전 빈 줄이면 현재 QA 쌍 저장
                qa_pairs.append({
                    'number': current_number,
                    'question': current_question,
                    'answer': ' '.join(current_answer).strip()
                })
                in_answer = False
                current_answer = []
            continue
            
        # 새로운 질문 확인 (Q 다음에 숫자가 오는 패턴)
        q_match = re.match(r'Q(\d+)\s+(.*)', line)
        if q_match:
            # 이전 QA 쌍이 있으면 저장
            if current_question is not None and current_answer:
                qa_pairs.append({
                    'number': current_number,
                    'question': current_question,
                    'answer': ' '.join(current_answer).strip()
                })
            
            # 새로운 질문 시작
            current_number = int(q_match.group(1))
            current_question = q_match.group(2).strip().rstrip('?') + '?'  # 질문 마크 정규화
            current_answer = []
            in_answer = False
            
        # 답변 시작 확인
        elif line.startswith('A ') or (current_question and not current_answer and line):
            in_answer = True
            current_answer.append(line.lstrip('A '))
            
        # 기존 답변에 내용 추가
        elif current_question is not None and (in_answer or not line.startswith('Q')):
            if in_answer or (current_answer and not line.startswith('Q')):
                current_answer.append(line)
    
    # 마지막 QA 쌍 처리
    if current_question is not None and current_answer:
        qa_pairs.append({
            'number': current_number,
            'question': current_question,
            'answer': ' '.join(current_answer).strip()
        })
    
    # 번호 순서대로 정렬
    qa_pairs.sort(key=lambda x: x['number'])
    
    return qa_pairs

# %%
# QA 쌍 추출
qa_pairs = extract_qa_pairs(docs[0].page_content) 

print(f"추출된 QA 쌍 개수: {len(qa_pairs)}")
print(f"추출된 첫번째 QA: \n{qa_pairs[0]}")
# Out:
# 추출된 QA 쌍 개수: 50
# 추출된 첫번째 QA:
# {'number': 1, 'question': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?', 'answer': '해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.'}

# %% [markdown]
# `(2) LLM으로 추가 정보를 추출`
# - 텍스트에서 키워드와 핵심 개념을 추출하는 체인
# - 메타데이터 or 본문(page_content)에 추가하여 검색에 활용

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from typing import List


# 출력 형식 정의
class KeywordOutput(BaseModel):
    keyword: str = Field(description="텍스트에서 추출한 가장 중요한 키워드(법률용어, 주제 등))")
    summary: str = Field(description="텍스트의 간단한 요약")

# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 텍스트 분석 전문가입니다. 
주어진 텍스트에서 중요한 키워드를 추출하고, 텍스트의 간단한 요약을 작성하는 것이 당신의 역할입니다.

## 추출 지침:
- 텍스트의 맥락을 고려하여 핵심 용어나 전문 용어를 추출합니다
- 주요 아이디어나 원리, 개념을 포함합니다
- 가장 중요한 키워드를 1개 추출합니다
- 요약은 1문장으로 간결하게 작성합니다

## 출력 형식:
- keyword: 가장 중요한 키워드 
- summary: 텍스트의 간단한 요약"""),
    
    ("user", "다음 텍스트를 분석해주세요:\n\n{input_text}")
])

# LCEL 체인 구성
llm_with_structure = llm.with_structured_output(KeywordOutput) 
keyword_extractor = prompt | llm_with_structure

# 텍스트 추출 테스트     
result = keyword_extractor.invoke(qa_pairs[0]['question']+qa_pairs[0]['answer'])
print("키워드:", result.keyword)
print("요약:", result.summary)
# Out:
# 키워드: 해당 주택건설지역
# 요약: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역은 과천시 행정구역 전체를 의미한다.

# %% [markdown]
# `(3) QA 쌍을 문자열 포맷팅하고 문서 객체로 변환`

# %%
from langchain_core.documents import Document

def format_qa_pairs(qa_pairs):
    """
    추출된 QA 쌍을 포맷팅하여 문서 객체로 변환
    """
    processed_docs = []
    for pair in qa_pairs:

        # QA 쌍을 포맷팅
        formatted_output = (
            f"[{pair['number']}]\n"
            f"질문: {pair['question']}\n"
            f"답변: {pair['answer']}\n"
        )

        # 키워드와 요약 추출
        result = keyword_extractor.invoke(pair['question']+"\n\n"+pair['answer'])

        # 문서 객체 생성
        doc = Document(
            page_content=formatted_output,
            metadata={
                'question_id': int(pair['number']),
                'question': pair['question'],
                'answer': pair['answer'],
                'keyword': result.keyword,
                'summary': result.summary
            }
        )
        processed_docs.append(doc)

    return processed_docs


# QA 쌍 포맷팅
formatted_docs = format_qa_pairs(qa_pairs)
print(f"포맷팅된 문서 개수: {len(formatted_docs)}")

# 문서 확인
print(formatted_docs[0].page_content)
print("-" * 200)
# 문서 메타데이터 확인
pprint(formatted_docs[0].metadata)
# Out:
# 포맷팅된 문서 개수: 50
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# {'answer': '해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 '
#            '말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 '
#            '주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 '
#            '전역이 해당 주택건설지역에 해당됩니다.',
#  'keyword': '해당 주택건설지역',
#  'question': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?',
#  'question_id': 1,
#  'summary': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역은 과천시 행정구역 전체를 의미한다.'}

# %%
# 문서 저장
output_file = "data/housing_faq_formatted.json"

with open(output_file, 'w', encoding='utf-8-sig') as f:
    json.dump([doc.model_dump() for doc in formatted_docs], f, indent=2, ensure_ascii=False)  # 한글이 유니코드로 변환되지 않도록 설정
print(f"포맷팅된 문서를 {output_file}에 저장했습니다.")
# Out:
# 포맷팅된 문서를 data/housing_faq_formatted.json에 저장했습니다.

# %% [markdown]
# ##### ***[실습] 문서 객체를 포맷팅하여 구성합니다.***
#
# - 요약문을 시맨틱 검색에 활용합니다. 다음 구조로 문서 객체를 생성합니다.
#     - page_content: 요약
#     - metadata: 기타 정보

# %%
# 여기에 코드를 작성하세요.

# %%
from langchain_core.documents import Document

def format_qa_pairs_with_summary(qa_pairs):
    """
    추출된 QA 쌍을 포맷팅하여 문서 객체로 변환
    """
    processed_docs = []
    for pair in qa_pairs:

        # 키워드와 요약 추출
        result = keyword_extractor.invoke(pair['question']+"\n\n"+pair['answer'])

        # 문서 객체 생성
        doc = Document(
            page_content=result.summary,
            metadata={
                'question_id': int(pair['number']),
                'question': pair['question'],
                'answer': pair['answer'],
                'keyword': result.keyword,
            }
        )
        processed_docs.append(doc)

    return processed_docs

# %%
# QA 쌍 포맷팅
summary_formatted_docs = format_qa_pairs_with_summary(qa_pairs) 
print(f"포맷팅된 문서 개수: {len(summary_formatted_docs)}")

# 문서 확인
print(summary_formatted_docs[0].page_content)
print("-" * 200)
# 문서 메타데이터 확인
pprint(summary_formatted_docs[0].metadata)
# Out:
# 포맷팅된 문서 개수: 50
# 경기도 과천시에서 공급되는 주택의 해당 주택건설지역은 과천시 행정구역 전체를 의미한다.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# {'answer': '해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 '
#            '말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 '
#            '주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 '
#            '전역이 해당 주택건설지역에 해당됩니다.',
#  'keyword': '해당 주택건설지역',
#  'question': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?',
#  'question_id': 1}

# %%
# 문서 저장
output_file = "data/housing_faq_formatted_with_summary.json"

with open(output_file, 'w', encoding='utf-8-sig') as f:
    json.dump([doc.model_dump() for doc in summary_formatted_docs], f, indent=2, ensure_ascii=False)  # 한글이 유니코드로 변환되지 않도록 설정
print(f"포맷팅된 문서를 {output_file}에 저장했습니다.")
# Out:
# 포맷팅된 문서를 data/housing_faq_formatted_with_summary.json에 저장했습니다.

# %% [markdown]
# # 벡터 저장

# %%
# 문서 로드
from langchain_core.documents import Document

output_file = "data/housing_faq_formatted.json"

with open(output_file, 'r', encoding='utf-8-sig') as f:
    formatted_docs = [Document(**doc) for doc in json.load(f)]

# 문서 확인
print(formatted_docs[0].page_content)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.

# %%
print(formatted_docs[0].metadata)
# Out:
# {'question_id': 1, 'question': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?', 'answer': '해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.', 'keyword': '해당 주택건설지역', 'summary': '경기도 과천시에서 공급되는 주택의 해당 주택건설지역은 과천시 행정구역 전체를 의미한다.'}

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 문서 벡터 저장
vector_store = Chroma.from_documents(  # 저장하는 코드 중복저장 안되도록 주의해야 함.
    documents=formatted_docs,
    embedding=embeddings,
    collection_name="housing_faq_db",
    persist_directory="./chroma_db",
)

# %%
vector_store._collection.count()
# Out:
# 100

# %%
# vector_store.delete_collection()

# %% [markdown]
# ##### ***[실습] 요약 문서(summary_formatted_docs)를 벡터 스토어에 저장합니다.***
#
# - OpenAI (text-embedding-3-small) 임베딩 모델 사용
# - Chroma DB 사용
#
# **힌트**:
# 1. `Chroma.from_documents()` 메소드 사용
# 2. `embedding` 파라미터에 OpenAIEmbeddings 인스턴스 전달
# 3. `collection_name`과 `persist_directory` 지정
# 4. `summary_formatted_docs` 변수 사용

# %%
# 여기에 코드를 작성하세요.

# %%
# 문서 로드
from langchain_core.documents import Document

output_file = "data/housing_faq_formatted_with_summary.json"

with open(output_file, 'r', encoding='utf-8-sig') as f:
    summary_formatted_docs = [Document(**doc) for doc in json.load(f)]

# 문서 확인
print(summary_formatted_docs[0].page_content)

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 문서 벡터 저장
vector_store_summary = None

print(vector_store_summary._collection.count())

# %% [markdown]
# # 문서 검색

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 벡터 저장소 로드
vector_store = Chroma(
    collection_name="housing_faq_db",
    persist_directory="./chroma_db", 
    embedding_function=embeddings,
)

vector_store._collection.count()
# Out:
# 100

# %% [markdown]
# ##### ***[실습] 앞에서 저장한 요약문서 벡터 스토어를 로드합니다.***
#
# - OpenAI (text-embedding-3-small) 임베딩 모델 사용
# - Chroma DB 사용
#
# **힌트**:
# 1. `Chroma()` 생성자 사용 (from_documents가 아님)
# 2. 저장 시 사용한 `collection_name`, `persist_directory` 동일하게 지정
# 3. `embedding_function` 파라미터에 OpenAIEmbeddings 전달

# %%
# 여기에 코드를 작성하세요.


# 벡터 저장소 로드
vector_store_summary = None

# %%
# 검색기 생성 - 유사도 기반 상위 3개 문서 검색
retriever = vector_store.as_retriever(
    search_kwargs={"k": 3},
)

# 테스트 질문
query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# --------------------------------------------------
# 청약신청 자격
# 2
# ==================================================

# %% [markdown]
# #### MMR (Maximal Marginal Relevance)
#
# MMR은 검색 결과의 **관련성**과 **다양성**을 동시에 고려하는 알고리즘입니다.
#
# **주요 파라미터**:
# - `fetch_k`: 초기 검색 문서 수 (유사도 기준)
# - `k`: 최종 반환 문서 수
# - `lambda_mult`: 다양성 가중치
#   - `0.0`: 최대 다양성 (서로 다른 문서 우선)
#   - `1.0`: 최대 관련성 (유사도만 고려)
#   - `0.5`: 균형 (관련성과 다양성을 동등하게)

# %% [markdown]
# ##### ***[실습] MMR 검색기를 정의합니다.***
#
# - 문서 벡터 스토어를 사용
# - 10개의 문서를 가져와서, 다양성 기반으로 3개를 선택 (다양성은 중간 수준 적용)
#
# **힌트**:
# 1. `vector_store.as_retriever()` 메소드 사용
# 2. `search_type="mmr"` 파라미터 지정
# 3. `search_kwargs`에 `fetch_k=10`, `k=3`, `lambda_mult=0.5` 설정

# %%
# 여기에 코드를 작성하세요.

mmr_retriever = None

# 테스트 질문
query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = mmr_retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print(result.metadata['question'])
    print(result.metadata['answer'])
    print("=" * 50)

# %% [markdown]
# ### **[심화] 메타데이터 기반 필터링**
#
# - Chroma 문서: https://docs.trychroma.com/docs/querying-collections/metadata-filtering

# %%
# 단일 필드 정확히 일치
retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"keyword": "해당 주택건설지역"}, "k":5},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================

# %%
# $eq 연산자 사용 - 정확히 일치

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"keyword": {"$eq": "해당 주택건설지역"}}},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================

# %%
# $ne (Not Equal) 연산자 사용 - 정확히 일치하지 않는 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"keyword": {"$ne": "해당 주택건설지역"}}},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# --------------------------------------------------
# 청약신청 자격
# 2
# ==================================================
# [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# --------------------------------------------------
# 청약신청 자격
# 2
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================

# %%
# $in 연산자로 여러 값 중 일치하는 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"keyword": {"$in": ["해당 주택건설지역", "청약예금"]}}},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [39]
# 질문: 인천광역시 거주자로 청약예금 400만원(전용면적 102㎡ 이하)에 가입한 자가 입주자 모집공고일 전 서울시로 이주한 경우 102㎡ 이하의 주택에 청약하려면?
# 답변: 서울의 경우 전용면적 102㎡ 이하 주택에 청약할 수 있는 예치금액은 600만원이기 때문에 청약접수 당일까지 부족금액인 200만원을 추가로 예치하여야만 102㎡ 이하의 주택에 청약이 가능
#
# --------------------------------------------------
# 청약예금
# 39
# ==================================================
# [39]
# 질문: 인천광역시 거주자로 청약예금 400만원(전용면적 102㎡ 이하)에 가입한 자가 입주자 모집공고일 전 서울시로 이주한 경우 102㎡ 이하의 주택에 청약하려면?
# 답변: 서울의 경우 전용면적 102㎡ 이하 주택에 청약할 수 있는 예치금액은 600만원이기 때문에 청약접수 당일까지 부족금액인 200만원을 추가로 예치하여야만 102㎡ 이하의 주택에 청약이 가능
#
# --------------------------------------------------
# 청약예금
# 39
# ==================================================

# %%
# 숫자 범위 검색 ($gt, $gte, $lt, $lte) - question_id가 10 이상인 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"question_id": {"$gte": 10}}},
)

query = "무주택자 기준은 무엇인가요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [50]
# 질문: 무주택자인 아내가 유주택자인 남편과 주민등록표상 분리되어 친정부모의 세대별 주민등록표에 등재되어 있는 경우, 무주택자인 친정부모는 무주택세대구성원 자격이 인정되는지?
# 답변: 친정부모의 세대원 범위에 세대분리된 직계비속의 배우자(사위)는 포함되지 않으므로 사위가 주택을 소유하고 있다 하더라도 무주택세대구성원으로 인정됩니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 50
# ==================================================
# [50]
# 질문: 무주택자인 아내가 유주택자인 남편과 주민등록표상 분리되어 친정부모의 세대별 주민등록표에 등재되어 있는 경우, 무주택자인 친정부모는 무주택세대구성원 자격이 인정되는지?
# 답변: 친정부모의 세대원 범위에 세대분리된 직계비속의 배우자(사위)는 포함되지 않으므로 사위가 주택을 소유하고 있다 하더라도 무주택세대구성원으로 인정됩니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 50
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================

# %%
# $and로 여러 조건 조합 - keyword가 "주택건설지역"이고 question_id가 10 미만인 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"$and": [
        {"keyword": "해당 주택건설지역"}, 
        {"question_id": {"$lt": 10}}
    ]}},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================

# %%
# $or로 여러 조건 중 하나 일치하는 문서 검색 - keyword가 "주택건설지역"이거나 question_id가 10 이상인 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={"filter": {"$or": [
        {"keyword": "해당 주택건설지역"}, 
        {"question_id": {"$gte": 10}}
    ]}},
)

query = "수원시의 주택건설지역은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================
# [47]
# 질문: 무주택세대구성원이란?
# 답변: 무주택세대구성원이란 청약신청자 및 세대원 전원이 주택을 소유하고 있지 않은 세대의 구성원(세대주 포함)을 말합니다.
#
# --------------------------------------------------
# 무주택세대구성원
# 47
# ==================================================

# %%
# 정규식 패턴 매칭 - page_content 본문에 "주택건설지역"이 포함된 문서 검색

retriever = vector_store.as_retriever(
    search_kwargs={'where_document': {'$contains': '해당 주택건설지역'}},
)

query = "수원시의 '해당 주택건설지역'은 어디에 해당하나요?"

results = retriever.invoke(query)
for result in results:
    print(result.page_content)
    print("-" * 50)
    print(result.metadata['keyword'])
    print(result.metadata['question_id'])
    print("=" * 50)
# Out:
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# --------------------------------------------------
# 해당 주택건설지역
# 1
# ==================================================
# [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# --------------------------------------------------
# 청약신청 자격
# 2
# ==================================================
# [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# --------------------------------------------------
# 청약신청 자격
# 2
# ==================================================

# %% [markdown]
# ##### ***[실습] 메타데이터 필터링 조건을 적용하는 실습을 수행합니다..***
#
# - 요약 문서 벡터 스토어 기반 MMR 검색기에 적용

# %%
# 여기에 코드를 작성하세요.

# 1. 요약 문서 벡터 스토어 기반 MMR 검색기 정의 (메타데이터 필터 적용)
mmr_filtered_retriever = vector_store_summary.as_retriever(
    search_type="mmr",
    search_kwargs={
        "k": 3,              # 최종 반환할 문서 개수
        "fetch_k": 10,       # 초기에 유사도 기준으로 뽑을 문서 개수
        "lambda_mult": 0.5,  # 다양성 가중치 (0.5는 관련성과 다양성의 균형)
        "filter": {"keyword": "해당 주택건설지역"}  # 메타데이터 필터 조건 추가
    }
)

# 2. 테스트 질문 정의
query = "수원시의 주택건설지역은 어디에 해당하나요?"

# 3. 검색 수행
results = mmr_filtered_retriever.invoke(query)

# 4. 결과 확인
print(f"검색된 문서 개수: {len(results)}\n")
for result in results:
    print("[요약 내용 (page_content)]")
    print(result.page_content)
    print("-" * 50)
    print("메타데이터:")
    print(f" - 질문 ID: {result.metadata.get('question_id')}")
    print(f" - 키워드: {result.metadata.get('keyword')}")
    print(f" - 원본 질문: {result.metadata.get('question')}")
    print("=" * 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 # 여기에 코드를 작성하세요.
#       2
#       3 # 1. 요약 문서 벡터 스토어 기반 MMR 검색기 정의 (메타데이터 필터 적용)
# ----> 4 mmr_filtered_retriever = vector_store_summary.as_retriever(
#       5     search_type="mmr",
#       6     search_kwargs={
#       7         "k": 3,              # 최종 반환할 문서 개수
#
# NameError: name 'vector_store_summary' is not defined

# %% [markdown]
# ### 메타데이터 필터 LLM 추출

# %%
from pydantic import BaseModel, Field
from typing import Optional, Literal


class MetadataFilter(BaseModel):
    """Chroma DB 메타데이터 필터 조건"""

    # 키워드 필터
    keyword: Optional[str] = Field(default=None, description="검색할 키워드")
    keyword_operator: Optional[Literal["$eq", "$ne"]] = Field(
        default=None, description="키워드 비교 연산자"
    )

    # 질문 ID 범위 (하한)
    question_id_min: Optional[int] = Field(default=None, description="질문 ID 최소값")
    question_id_min_operator: Optional[Literal["$gt", "$gte"]] = Field(
        default=None, description="최소값 연산자 ($gt: 초과, $gte: 이상)"
    )

    # 질문 ID 범위 (상한)
    question_id_max: Optional[int] = Field(default=None, description="질문 ID 최대값")
    question_id_max_operator: Optional[Literal["$lt", "$lte"]] = Field(
        default=None, description="최대값 연산자 ($lt: 미만, $lte: 이하)"
    )

    # 논리 연산자
    logical_operator: Optional[Literal["$and", "$or"]] = Field(
        default="$and", description="복합 조건 결합 연산자"
    )

# %%
from langchain_core.prompts import ChatPromptTemplate

# 시스템 프롬프트
METADATA_FILTER_SYSTEM_PROMPT = """사용자 쿼리에서 Chroma DB 검색 필터 조건을 추출합니다.

## 추출 규칙

### 키워드 (keyword)
- 특정 단어/주제 검색 시 해당 키워드 추출
- keyword_operator: 일반적으로 "$eq" 사용

### 질문 ID 범위
- "N번 이상": question_id_min=N, question_id_min_operator="$gte"
- "N번 초과": question_id_min=N, question_id_min_operator="$gt"
- "N번 이하": question_id_max=N, question_id_max_operator="$lte"
- "N번 미만": question_id_max=N, question_id_max_operator="$lt"
- "N~M번 사이": 최소값과 최대값 모두 설정

### 논리 연산자
- 모든 조건 만족: "$and" (기본값)
- 하나라도 만족: "$or"

## 예시

1. 키워드만: "주택건설 관련 문서"
   → keyword="주택건설", keyword_operator="$eq"

2. ID 범위: "10번 이상 20번 이하"
   → question_id_min=10, question_id_min_operator="$gte",
     question_id_max=20, question_id_max_operator="$lte"

3. 복합 조건: "청약통장 관련 40~50번 문서"
   → keyword="청약통장", keyword_operator="$eq",
     question_id_min=40, question_id_min_operator="$gte",
     question_id_max=50, question_id_max_operator="$lte",
     logical_operator="$and"

해당 정보가 없으면 null 반환.
"""

# 메타데이터 추출 체인 구성
metadata_extraction_chain = (
    ChatPromptTemplate.from_messages([
        ("system", METADATA_FILTER_SYSTEM_PROMPT),
        ("human", "{query}")
    ])
    | llm.with_structured_output(MetadataFilter)
)

# 테스트: 필터 조건 추출
query = "'해당 주택건설지역' 관련 문서를 10번 이하인 문서중에서 검색해주세요"
filter_params = metadata_extraction_chain.invoke({"query": query})

print("추출된 필터 파라미터:")
print(filter_params.model_dump())
# Out:
# 추출된 필터 파라미터:
# {'keyword': '해당 주택건설지역', 'keyword_operator': '$eq', 'question_id_min': None, 'question_id_min_operator': None, 'question_id_max': 10, 'question_id_max_operator': '$lte', 'logical_operator': '$and'}

# %%
def build_chroma_filter(filter_params: MetadataFilter) -> dict:
    """MetadataFilter를 Chroma DB 필터 딕셔너리로 변환
    
    Args:
        filter_params: MetadataFilter 인스턴스
        
    Returns:
        Chroma DB where 절에 사용할 필터 딕셔너리
    """
    conditions = []

    # 키워드 조건
    if filter_params.keyword and filter_params.keyword_operator:
        conditions.append({
            "keyword": {filter_params.keyword_operator: filter_params.keyword}
        })

    # 질문 ID 최소값 조건
    if filter_params.question_id_min is not None and filter_params.question_id_min_operator:
        conditions.append({
            "question_id": {filter_params.question_id_min_operator: filter_params.question_id_min}
        })

    # 질문 ID 최대값 조건
    if filter_params.question_id_max is not None and filter_params.question_id_max_operator:
        conditions.append({
            "question_id": {filter_params.question_id_max_operator: filter_params.question_id_max}
        })

    # 조건 개수에 따른 필터 구성
    if len(conditions) == 0:
        return {}
    elif len(conditions) == 1:
        return conditions[0]
    else:
        logical_op = filter_params.logical_operator or "$and"
        return {logical_op: conditions}


# 테스트: 필터 딕셔너리 생성
filter_dict = build_chroma_filter(filter_params)
print("생성된 Chroma 필터:")
print(filter_dict)
# Out:
# 생성된 Chroma 필터:
# {'$and': [{'keyword': {'$eq': '해당 주택건설지역'}}, {'question_id': {'$lte': 10}}]}

# %%
from langchain_core.runnables import chain


@chain
def metadata_filter_retriever(query: str):
    """메타데이터 필터를 추출하고 검색 수행
    
    Args:
        query: 사용자 검색 쿼리
        
    Returns:
        검색된 문서 리스트
    """
    # 1. 필터 조건 추출
    filter_params = metadata_extraction_chain.invoke({"query": query})

    # 2. Chroma 필터로 변환
    filter_dict = build_chroma_filter(filter_params)
    print(f"추출된 필터: {filter_dict}")

    # 3. 검색 실행
    retriever = vector_store.as_retriever(
        search_kwargs={"filter": filter_dict} if filter_dict else {}
    )
    return retriever.invoke(query)


# 테스트 실행
query = "청약통장 관련 문서를 40번과 50번 사이의 문서 중에서 검색해주세요"
results = metadata_filter_retriever.invoke(query)

print(f"\n검색된 문서 수: {len(results)}")
for i, result in enumerate(results, 1):
    print(f"\n--- 문서 {i} ---")
    print(f"내용: {result.page_content[:100]}...")
    print(f"키워드: {result.metadata.get('keyword', 'N/A')}")
    print(f"질문 ID: {result.metadata.get('question_id', 'N/A')}")
# Out:
# 추출된 필터: {'$and': [{'keyword': {'$eq': '청약통장'}}, {'question_id': {'$gte': 40}}, {'question_id': {'$lte': 50}}]}
#
# 검색된 문서 수: 2
#
# --- 문서 1 ---
# 내용: [43]
# 질문: 청약통장이 압류 등으로 사용에 제한이 있거나, 청약통장 담보대출을 받고 있는 경우에도 해당 통장을 이용하여 당첨이 가능한지?
# 답변: 압류 등의 상태라고 하더라도 청...
# 키워드: 청약통장
# 질문 ID: 43
#
# --- 문서 2 ---
# 내용: [43]
# 질문: 청약통장이 압류 등으로 사용에 제한이 있거나, 청약통장 담보대출을 받고 있는 경우에도 해당 통장을 이용하여 당첨이 가능한지?
# 답변: 압류 등의 상태라고 하더라도 청...
# 키워드: 청약통장
# 질문 ID: 43

# %%
# 다양한 쿼리 테스트
test_queries = [
    "청약통장 관련 문서 찾아줘",        # 키워드만
    "질문 ID 10번 이상인 문서",         # ID 하한만
    "20번 이하 문서만 보여줘",          # ID 상한만
    "10번에서 30번 사이 문서",          # ID 범위
    "'해당 주택건설지역' 관련 10번 이하 문서",  # 복합
    "청약통장 관련 40~50번 문서",       # 복합 + 범위
]

for query in test_queries:
    print(f"\n{'='*60}")
    print(f"쿼리: {query}")
    print('='*60)
    
    # 필터 추출 및 검색
    filter_params = metadata_extraction_chain.invoke({"query": query})
    filter_dict = build_chroma_filter(filter_params)
    print(f"필터: {filter_dict}")
    
    # 검색 실행
    results = metadata_filter_retriever.invoke(query)
    print(f"검색 결과: {len(results)}건")
    
    if results:
        print(f"첫 번째 문서 - 키워드: {results[0].metadata.get('keyword')}, ID: {results[0].metadata.get('question_id')}")
# Out:
# ============================================================
# 쿼리: 청약통장 관련 문서 찾아줘
# ============================================================
# 필터: {'keyword': {'$eq': '청약통장'}}
# 추출된 필터: {'keyword': {'$eq': '청약통장'}}
# 검색 결과: 2건
# 첫 번째 문서 - 키워드: 청약통장, ID: 43
#
# ============================================================
# 쿼리: 질문 ID 10번 이상인 문서
# ============================================================
# 필터: {'question_id': {'$gte': 10}}
# 추출된 필터: {'question_id': {'$gte': 10}}
# 검색 결과: 4건
# 첫 번째 문서 - 키워드: 거주기간 인정, ID: 20
#
# ============================================================
# 쿼리: 20번 이하 문서만 보여줘
# ============================================================
# 필터: {'question_id': {'$lte': 20}}
# 추출된 필터: {'question_id': {'$lte': 20}}
# 검색 결과: 4건
# 첫 번째 문서 - 키워드: 거주기간 인정, ID: 20
#
# ============================================================
# 쿼리: 10번에서 30번 사이 문서
# ============================================================
# 필터: {'$and': [{'question_id': {'$gte': 10}}, {'question_id': {'$lte': 30}}]}
# 추출된 필터: {'$and': [{'question_id': {'$gte': 10}}, {'question_id': {'$lte': 30}}]}
# 검색 결과: 4건
# 첫 번째 문서 - 키워드: 예치금 정정 불가, ID: 23
#
# ============================================================
# 쿼리: '해당 주택건설지역' 관련 10번 이하 문서
# ============================================================
# 필터: {'$and': [{'keyword': {'$eq': '해당 주택건설지역'}}, {'question_id': {'$lte': 10}}]}
# 추출된 필터: {'$and': [{'keyword': {'$eq': '해당 주택건설지역'}}, {'question_id': {'$lte': 10}}]}
# 검색 결과: 2건
# 첫 번째 문서 - 키워드: 해당 주택건설지역, ID: 1
#
# ============================================================
# 쿼리: 청약통장 관련 40~50번 문서
# ============================================================
# 필터: {'$and': [{'keyword': {'$eq': '청약통장'}}, {'question_id': {'$gte': 40}}, {'question_id': {'$lte': 50}}]}
# 추출된 필터: {'$and': [{'keyword': {'$eq': '청약통장'}}, {'question_id': {'$gte': 40}}, {'question_id': {'$lte': 50}}]}
# 검색 결과: 2건
# 첫 번째 문서 - 키워드: 청약통장, ID: 43

# %% [markdown]
# ##### ***[실습] 메타데이터 필터링 체인의 성능을 개선합니다.***
#
# - (예시)
#     - 추가 예시 제공을 통해 필터링 적용 법위 확대

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# # RAG Chain

# %% [markdown]
# ### 1) 참조 문서 없이 직접 답변을 생성

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# Prompt
template = '''Answer the question based only on the following context.

[Context]
{context}

[Question]
{question}

[Answer (in 한국어)]
'''

prompt = ChatPromptTemplate.from_template(template)


# 문서 포맷팅
def format_docs(docs):
    return '\n\n'.join([d.page_content for d in docs])


# 검색기 생성 - 유사도 기반 상위 3개 문서 검색
retriever = vector_store.as_retriever(
    search_kwargs={"k": 3},
)


# Chain 구성
rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Chain 실행
query = "수원시의 주택건설지역은 어디에 해당하나요?"
rag_chain.invoke(query)
# Out:
# '수원시는 경기도에 속하는 시이므로, 수원시에서 공급되는 주택의 해당 주택건설지역은 수원시 행정구역 전체에 해당됩니다.'

# %% [markdown]
# ### 2) 참조 문서를 답변과 함께 반환

# %% [markdown]
# `(1) 문서와 포맷팅된 컨텍스트를 함께 반환하는 함수`

# %%
from typing import Dict

def get_context_and_docs(question: str) -> Dict:
    """문서와 포맷팅된 컨텍스트를 함께 반환
    
    Args:
        question: 검색할 질문

    Returns:
        Dict: 문서와 포맷팅된 컨텍스트, 검색된 문서 리스트
    """

    # 검색 결과 가져오기
    docs = retriever.invoke(question)
    return {
        "question": question,  # 질문
        "context": format_docs(docs),   # 문서 포맷팅된 컨텍스트
        "source_documents": docs   # 검색된 문서 리스트
    }

# %% [markdown]
# `(2) 컨텍스트와 질문을 입력으로 받아 답변을 생성하는 함수`

# %%
from langchain_core.output_parsers import StrOutputParser

def prompt_and_generate_answer(input_data: Dict) -> Dict:
    """컨텍스트와 질문을 입력으로 받아 답변을 생성

    Args:
        input_data (Dict): 컨텍스트와 질문이 포함된 딕셔너리

    Returns:
        Dict: 생성된 답변과 소스 문서 정보가 포함된 딕셔너리
    """

    # LCEL 체인 구성 (StrOutputParser 사용)
    answer_chain = prompt | llm | StrOutputParser()
    answer = answer_chain.invoke({
        "question":input_data["question"],
        "context":input_data["context"]
    })

    return {
        "answer": answer,  # 생성된 답변 (answer_chain 결과)
        "source_documents": input_data["source_documents"]  # 소스 문서 정보 (input_data에서 가져옴)
    }

# %% [markdown]
# `(3) RAG 체인 구성`

# %%
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from operator import itemgetter

# Chain 구성
rag_chain = (
    RunnableLambda(get_context_and_docs) |  # 문서와 컨텍스트 가져오기 
    {
        'response': RunnableLambda(prompt_and_generate_answer), # 답변 생성
        'question': itemgetter("question"),  # 질문 그대로 전달
        "source_documents": itemgetter("source_documents")   # 소스 반환
    }
)

# %%
# Chain 실행
query = "수원시의 주택건설지역은 어디에 해당하나요?"
result = rag_chain.invoke(query)

# 결과 출력
print("답변:", result["response"]["answer"])
print("\n참조 문서:")
for i, doc in enumerate(result["source_documents"], 1):
    print(f"\n문서 {i}:")
    print(f"내용: {doc.page_content}")
# Out:
# 답변: 수원시는 경기도에 속하는 시이므로, 수원시에서 공급되는 주택의 해당 주택건설지역은 수원시 행정구역 전체에 해당됩니다.
#
# 참조 문서:
#
# 문서 1:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
#
# 문서 2:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
#
# 문서 3:
# 내용: [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.

# %% [markdown]
# ### 3) 검색 문서 관련성 평가

# %% [markdown]
# `(1) 검색 문서와 질문 간의 관련성을 평가`

# %%
# 검색 문서의 질문 관련성 평가

prompt = ChatPromptTemplate.from_messages([
    ("system", """주어진 컨텍스트가 질문에 답변하는데 필요한 정보를 포함하고 있는지 논리적으로 평가하세요.
단계적으로 진행하며, 평가결과에 대한 검증을 수행하세요.

다음 기준 중 하나 이상을 충족할 경우 'Yes'로 답변하고, 모두 충족하지 못하면 'No'로 답변하세요:

1. 컨텍스트가 질문에 답변하는데 필요한 정보를 직접적으로 포함하고 있는가?
2. 컨텍스트의 정보로부터 답변에 필요한 내용을 논리적으로 추론할 수 있는가?
3. 컨텍스트의 정보가 질문에 대한 답변을 제공할 수 있는가?

'Yes' 또는 'No'로만 답변하세요."""),
    ("human", """[컨텍스트]
{context}

[질문]
{question}""")
])

chain = prompt | llm | StrOutputParser()    # gpt-4.1-mini 모델 사용

for i, doc in enumerate(result["source_documents"], 1):
    print(f"\n문서 {i}:")
    print(f"내용: {doc.page_content}")
    relevance = chain.invoke({
        "context": doc.page_content,
        "question": query
    }).lower()

    print(f"평가 결과: {relevance}")
# Out:
# 문서 1:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# 평가 결과: yes
#
# 문서 2:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# 평가 결과: yes
#
# 문서 3:
# 내용: [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# 평가 결과: no

# %%
# gpt-4.1 모델 사용

llm_gpt4o = ChatOpenAI(
    model='gpt-4.1',          # 사용할 모델
    temperature=0.1,          # 낮은 값: 일관된 답변 (0.0~2.0)
    top_p=0.9,                # 토큰 샘플링 확률 임계값 (0.0~1.0)
)

chain = prompt | llm_gpt4o | StrOutputParser()    # gpt-4.1 모델 사용

for i, doc in enumerate(result["source_documents"], 1):
    print(f"\n문서 {i}:")
    print(f"내용: {doc.page_content}")
    relevance = chain.invoke({
        "context": doc.page_content,
        "question": query
    }).lower()

    print(f"평가 결과: {relevance}")
# Out:
# 문서 1:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# 평가 결과: yes
#
# 문서 2:
# 내용: [1]
# 질문: 경기도 과천시에서 공급되는 주택의 해당 주택건설지역의 범위는?
# 답변: 해당 주택건설지역이란 특별시ㆍ광역시ㆍ특별자치시ㆍ특별자치도(관할 구역 안에 지방자치단체인 시ㆍ군이 없는 특별자치도를 말한다) 또는 시ㆍ군의 행정구역을 말합니다. 따라서, 경기도 과천시에서 공급하는 주택의 경우 과천시가 해당 주택건설지역에 해당됩니다. 참고로, 서울특별시에서 공급되는 주택의 경우 서울특별시 전역, 인천광역시의 경우 인천광역시 전역이 해당 주택건설지역에 해당됩니다.
#
# 평가 결과: yes
#
# 문서 3:
# 내용: [2]
# 질문: 해당 주택건설지역에 거주하고 있지 않다면 청약신청이 불가능한지?
# 답변: 해당 주택건설지역에 거주하고 있지 않더라도 청약가능지역에서 공급되는 주택에 청약신청이 가능하나, 같은 순위에서는 해당 주택건설지역의 거주자가 우선하여 주택을 공급받게 됩니다. * 서울·인천·경기도 / 대전·세종·충남 / 충북 / 광주·전남 / 전북 / 대구·경북 / 부산·울산·경남 / 강원 다만, 수도권 대규모 택지개발지구 등에서 주택이 공급되는 경우 일정 비율의 주택에 대해서는 해당 주택건설지역 거주자와 동등한 자격으로 주택을 공급받을 기회를 가지게 됩니다.
#
# 평가 결과: no

# %% [markdown]
# ##### ***[실습] 문서 관련성 평가 체인을 구조화 출력으로 구현합니다.***
#
# - pydantic schema 사용
# - with_structured_output 함수 사용

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## Gradio 챗봇 인터페이스 (RAG 시스템 클래스 구현)
#
# 다음 클래스는 RAG 시스템의 전체 파이프라인을 캡슐화합니다.
#
# **주요 메서드**:
# - `_format_docs()`: 검색된 문서를 컨텍스트 문자열로 변환
# - `_format_source_documents()`: 참조 문서를 사용자 친화적 형식으로 포맷
# - `_evaluate_relevance()`: 검색된 문서의 질문 관련성 평가
# - `_generate_answer()`: 컨텍스트 기반 답변 생성
# - `generate_answer()`: Gradio 인터페이스용 메인 함수
#
# **클래스 구조**:
# 1. LLM 초기화 (답변 생성용, 관련성 평가용)
# 2. 벡터 스토어 검색기 설정
# 3. 프롬프트 템플릿 정의
# 4. RAG 체인 구성

# %%
import gradio as gr
from langchain_core.language_models import BaseChatModel
from langchain_core.vectorstores import VectorStoreRetriever
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from typing import List, Optional, Generator
from dataclasses import dataclass

@dataclass
class SearchResult:
    context: str
    source_documents: Optional[List]

class RAGSystem:
    def __init__(
            self, 
            llm: BaseChatModel, 
            eval_llm: BaseChatModel,
            retriever: VectorStoreRetriever
        ):
        if not llm:
            self.llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
        else:
            self.llm = llm

        if not eval_llm:
            self.eval_llm = ChatOpenAI(model="gpt-4.1", temperature=0)
        else:
            self.eval_llm = eval_llm

        if not retriever:
            raise ValueError("검색기(retriever)가 필요합니다.")
        else:
            self.retriever = retriever
        
    def _format_docs(self, docs: List) -> str:
        return "\n\n".join(doc.page_content for doc in docs)
    
    def _format_source_documents(self, docs: Optional[List]) -> str:
        if not docs:
            return "\n\nℹ️ 관련 문서를 찾을 수 없습니다."
        
        formatted_docs = []
        for i, doc in enumerate(docs, 1):
            metadata = doc.metadata if hasattr(doc, 'metadata') else {}
            source_info = []
            
            if 'question_id' in metadata:
                source_info.append(f"ID: {metadata['question_id']}")
            if 'keyword' in metadata:
                source_info.append(f"키워드: {metadata['keyword']}")
            if 'summary' in metadata:
                source_info.append(f"요약: {metadata['summary']}")
                
            formatted_docs.append(
                f"📚 참조 문서 {i}\n"
                f"• {' | '.join(source_info) if source_info else '출처 정보 없음'}\n"
                f"• 내용: {doc.page_content}"
            )
        
        return "\n\n" + "\n\n".join(formatted_docs)
    
    def _check_relevance(self, docs: List, question: str) -> List:
        """문서의 관련성 확인"""

        relevant_docs = []

        if not docs:
            return relevant_docs
            
        prompt = ChatPromptTemplate.from_messages([
            ("system", """주어진 컨텍스트가 질문에 답변하는데 필요한 정보를 포함하고 있는지 평가하세요.

        다음 기준 중 하나 이상을 충족할 경우 'Yes'로 답변하고, 모두 충족하지 못하면 'No'로 답변하세요:

        1. 컨텍스트가 질문에 답변하는데 필요한 정보를 직접적으로 포함하고 있는가?
        2. 컨텍스트의 정보로부터 답변에 필요한 내용을 논리적으로 추론할 수 있는가?

        'Yes' 또는 'No'로만 답변하세요."""),
            ("human", """[컨텍스트]
        {context}

        [질문]
        {question}""")
        ])
        
        chain = prompt | self.eval_llm | StrOutputParser()

        for doc in docs:
            result = chain.invoke({
                "context": doc.page_content,
                "question": question
            }).lower()

            print(f"문서 {doc.metadata['question_id']} 관련성 확인 결과: {result}")
            print(f"문서 {doc.metadata['question_id']} 내용:")
            print(doc.page_content)
            print("-" * 50)

            if "yes" in result:
                relevant_docs.append(doc)
            
        return relevant_docs
    
    def search_documents(self, question: str) -> SearchResult:
        try:
            docs = retriever.invoke(question)
            print(f"검색된 문서 개수: {len(docs)}")
            relevant_docs = self._check_relevance(docs, question) 
            print(f"관련 문서 개수: {len(relevant_docs)}")
            
            return SearchResult(
                context=self._format_docs(relevant_docs) if relevant_docs else "관련 문서를 찾을 수 없습니다.",
                source_documents=relevant_docs,
            )
        except Exception as e:
            print(f"문서 검색 중 오류 발생: {e}")
            return SearchResult(
                context="문서 검색 중 오류가 발생했습니다.",
                source_documents=None,
            )
    
    def generate_answer(self, message: str, history: List) -> Generator[str, None, None]:
            """Gradio 스트리밍 출력을 위한 제너레이터 함수"""
            
            # 1. 문서 검색 
            search_result = self.search_documents(message)
            
            if not search_result.source_documents:
                yield "죄송합니다. 관련 문서를 찾을 수 없어 답변하기 어렵습니다. 다른 질문을 해주시겠습니까?"
                return
                        
            # 2. 프롬프트 템플릿 설정
            prompt = ChatPromptTemplate.from_messages([
                ("system", """다음 지침을 따라 질문에 답변해주세요:
                1. 주어진 문서의 내용만을 기반으로 답변하세요.
                2. 문서에 명확한 근거가 없는 내용은 "근거 없음"이라고 답변하세요.
                3. 답변하기 어려운 질문은 "잘 모르겠습니다"라고 답변하세요.
                4. 추측이나 일반적인 지식을 사용하지 마세요."""),
                ("human", "문서들:\n{context}\n\n질문: {question}")
            ])
            
            # 3. RAG Chain 구성
            chain = prompt | self.llm | StrOutputParser()
            
            full_answer = ""
            try:
                # 4. 스트리밍 실행 (chain.stream 사용)
                for chunk in chain.stream({
                    "context": search_result.context,
                    "question": message
                }):
                    full_answer += chunk
                    # 현재까지 생성된 텍스트를 Gradio UI에 즉시 반영
                    yield full_answer
                
                # 5. 답변 생성이 완료된 후 참조 문서 추가
                sources = self._format_source_documents(search_result.source_documents)
                final_response = f"{full_answer}\n\n---\n{sources}"
                yield final_response
                
            except Exception as e:
                yield f"답변 생성 중 오류가 발생했습니다: {str(e)}"

# Gradio 인터페이스 설정

rag_system = RAGSystem(
    llm=ChatOpenAI(model="gpt-4.1-nano", temperature=0),   
    eval_llm=ChatOpenAI(model="gpt-4.1-mini", temperature=0),
    retriever=vector_store.as_retriever(search_kwargs={"k": 3})
)

demo = gr.ChatInterface(
    fn=rag_system.generate_answer,
    title="RAG QA 시스템",
    description="""
    질문을 입력하면 관련 문서를 검색하여 답변을 생성합니다.
    모든 답변에는 참조한 문서의 출처가 표시됩니다.
    """,
    examples=[
        ["수원시의 주택건설지역은 어디에 해당하나요?"],
        ["무주택 세대에 대해서 설명해주세요."],
        ["2순위로 당첨된 사람이 청약통장을 다시 사용할 수 있나요?"],
    ],
)

# 데모 실행
demo.launch()

# %%
# Gradio 인터페이스 종료
demo.close()

# %% [markdown]
# ---
#
# # **[실습] 주택청약 FAQ 시스템 구현**
#
# ### **문제 설명**
# 이전 코드를 기반으로 주택청약 FAQ 시스템을 다음 요구사항에 맞춰 개선합니다.
#
# 1. 응답 품질 향상 (1개 이상)
#    - 생성된 답변의 품질을 평가 (답변이 불충분한 경우 예외 처리)
#    - 관련성 높은 FAQ 문서 검색 (임베딩 모델, 청크 크기, 벡터 검색 방법 등)
#
# 2. 사용자 경험 개선 (1개 이상)
#    - 대화 이력 관리 기능 추가 (요약, 트리밍 기능 등 고려)
#    - 최근 대화 기반 컨텍스트 구성
#    - 사용자 프로필 기반 맞춤 응답
#
# ### **제약 조건**
# - Gradio ChatInterface 사용
# - RAG 구조 유지

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# # **사내 문서 기반 FAQ 시스템**
#
# ### **문제 설명**
# 이전 코드를 기반으로 주택청약 FAQ 시스템을 다음 요구사항에 맞춰 개선합니다.
#
# 1. 응답 품질 향상 (1개 이상)
#    - 생성된 답변의 품질을 평가 (답변이 불충분한 경우 예외 처리)
#    - 관련성 높은 FAQ 문서 검색 (임베딩 모델, 청크 크기, 벡터 검색 방법 등)
#
# 2. 사용자 경험 개선 (1개 이상)
#    - 대화 이력 관리 기능 추가 (요약, 트리밍 기능 등 고려)
#    - 최근 대화 기반 컨텍스트 구성
#    - 사용자 프로필 기반 맞춤 응답
#
# ### **제약 조건**
# - Gradio ChatInterface 사용
# - RAG 구조 유지

# %% [markdown]
# ## 프로세스
#
# 기존 주택청약 FAQ 시스템에서 도메인을 변경하여 사내 문서(PDF, Excel, PPT) 기반 QA 챗봇으로 확장하였습니다.
#
# ## 1. 데이터 수집 개선
# - TXT FAQ → 사내 문서(PDF, Excel, PPT)로 확장
# - `data/company/` 하위 문서 자동 수집
#
# ## 2. 검색 품질 개선
# - 문서 청킹 적용
#   - chunk_size=1000
#   - chunk_overlap=200
# - Chroma Vector DB 사용
# - OpenAI Embedding(text-embedding-3-small) 적용
# - MMR 검색 적용으로 관련성 + 다양성 확보
#
# ## 3. 응답 품질 향상
# - LLM을 이용한 답변 품질 평가 추가
# - 답변이 부적절한 경우:
#
#   ```
#   관련 정보를 찾을 수 없습니다.
#   ```
#
#   로 예외 처리
#
# ## 4. 사용자 경험 개선
# - 최근 5개 대화 이력 반영
# - 이전 대화 문맥을 고려한 답변 제공
#
# ## 5. 신뢰성 개선
# - 답변 하단에 참고 문서 출처 표시
#
# 예시
#
# ```
# 📄 참고 문서
# ERP_업무매뉴얼.pdf
# 인사규정.xlsx
# ```
#
# ## 6. UI 구성
# - Gradio ChatInterface 사용
# - 예제 질문 제공
#
# ## 향후 개선 사항
# - 파일 업로드 기능 추가
# - 업로드 시 벡터 DB 자동 갱신
# - 사내 게시판/공유폴더 연동 => 보안 이슈 살펴보기..

# %% [markdown]
# ### 1. 특정 폴더 하위에 있는 파일(PDF, Excel, PPT) 수집
#
# - data/company/

# %%
from glob import glob

from langchain_community.document_loaders import (
    PyPDFLoader,
    UnstructuredPowerPointLoader,
    UnstructuredExcelLoader # 오류

)
import pandas as pd
from langchain_core.documents import Document

docs = []

# PDF
for file in glob("data/company/**/*.pdf", recursive=True):
    loader = PyPDFLoader(file)
    docs.extend(loader.load())

# PPT
for file in glob("data/company/**/*.pptx", recursive=True):

    loader = UnstructuredPowerPointLoader(file)

    ppt_docs = loader.load()

    for doc in ppt_docs:
        doc.metadata["source"] = file
        doc.metadata["filename"] = os.path.basename(file)

    docs.extend(ppt_docs)

# 엑셀
excel_docs = []

for file in glob("data/company/**/*.xlsx", recursive=True):

    sheets = pd.read_excel(
        file,
        sheet_name=None
    )

    for sheet_name, df in sheets.items():

        content = df.to_string()

        excel_docs.append(
            Document(
                page_content=content,
                metadata={
                    "source": file,
                    "sheet": sheet_name,
                    "filename": os.path.basename(file)
                }
            )
        )

docs.extend(excel_docs)

print(len(docs))
# Out:
# 73

# %% [markdown]
# ### 2. 문서 청킹
#
# - 텍스트 파일과 달리 사내 문서는 양식이 다양해서... 청킹 필수

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

split_docs = splitter.split_documents(docs)

print(len(split_docs))
# Out:
# 209

# %% [markdown]
# ### 3. 키워드 + 요약 생성
#
# - 키워드+요약 생성은 많은 시간이 소요되어 아래에 키워드 생성 제외한 스크립트로 실행하였음

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field
from typing import List

class KeywordOutput(BaseModel):
    keyword: str
    summary: str


processed_docs = []

for doc in split_docs:

    result = keyword_extractor.invoke(
        doc.page_content[:3000]
    )

    new_doc = Document(
        page_content=doc.page_content,

        metadata={
            "source": doc.metadata.get("source"),
            "page": doc.metadata.get("page"),

            "keyword": result.keyword,
            "summary": result.summary
        }
    )

    processed_docs.append(new_doc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 15
#      11 processed_docs = []
#      12
#      13 for doc in split_docs:
#      14
# ---> 15     result = keyword_extractor.invoke(
#      16         doc.page_content[:3000]
#      17     )
#      18
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\runnables\base.py:3335, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3333                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3334             else:
# -> 3335                 input_ = context.run(step.invoke, input_, config)
#    3336 # finish the root run
#    3337 except BaseException as e:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\runnables\base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1639, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1636 if "response_format" in payload:
#    1637     payload.pop("stream")
#    1638     raw_response = (
# -> 1639         self.root_client.chat.completions.with_raw_response.parse(**payload)
#    1640     )
#    1641     response = raw_response.parse()
#    1642 elif self._use_responses_api(payload):
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:191, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     184 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     185     return _parse_chat_completion(
#     186         response_format=response_format,
#     187         chat_completion=raw_completion,
#     188         input_tools=chat_completion_tools,
#     189     )
# --> 191 return self._post(
#     192     "/chat/completions",
#     193     body=maybe_transform(
#     194         {
#     195             "messages": messages,
#     196             "model": model,
#     197             "audio": audio,
#     198             "frequency_penalty": frequency_penalty,
#     199             "function_call": function_call,
#     200             "functions": functions,
#     201             "logit_bias": logit_bias,
#     202             "logprobs": logprobs,
#     203             "max_completion_tokens": max_completion_tokens,
#     204             "max_tokens": max_tokens,
#     205             "metadata": metadata,
#     206             "modalities": modalities,
#     207             "n": n,
#     208             "parallel_tool_calls": parallel_tool_calls,
#     209             "prediction": prediction,
#     210             "presence_penalty": presence_penalty,
#     211             "prompt_cache_key": prompt_cache_key,
#     212             "prompt_cache_retention": prompt_cache_retention,
#     213             "reasoning_effort": reasoning_effort,
#     214             "response_format": _type_to_response_format(response_format),
#     215             "safety_identifier": safety_identifier,
#     216             "seed": seed,
#     217             "service_tier": service_tier,
#     218             "stop": stop,
#     219             "store": store,
#     220             "stream": False,
#     221             "stream_options": stream_options,
#     222             "temperature": temperature,
#     223             "tool_choice": tool_choice,
#     224             "tools": tools,
#     225             "top_logprobs": top_logprobs,
#     226             "top_p": top_p,
#     227             "user": user,
#     228             "verbosity": verbosity,
#     229             "web_search_options": web_search_options,
#     230         },
#     231         completion_create_params.CompletionCreateParams,
#     232     ),
#     233     options=make_request_options(
#     234         extra_headers=extra_headers,
#     235         extra_query=extra_query,
#     236         extra_body=extra_body,
#     237         timeout=timeout,
#     238         post_parser=parser,
#     239         security={"bearer_auth": True},
#     240     ),
#     241     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     242     # in the `parser` function above
#     243     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     244     stream=False,
#     245 )
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1035 response = None
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#    1043     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_client.py:440, in OpenAI._send_request(self, request, stream, **kwargs)
#     432 @override
#     433 def _send_request(
#     434     self,
#    (...)    438     **kwargs: Unpack[HttpxSendArgs],
#     439 ) -> httpx.Response:
# --> 440     return self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_client.py:418, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     415         request.headers["Authorization"] = f"Bearer {self._workload_identity_auth.get_token()}"
#     416         used_workload_identity_auth = True
# --> 418 response = super()._send_request(request, stream=stream, **kwargs)
#     419 if (
#     420     response.status_code == 401
#     421     and self._workload_identity_auth is not None
#     422     and used_workload_identity_auth
#     423     and not retried
#     424 ):
#     425     response.close()
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\openai\_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\HVS\modu_llm7\faq_bot\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\ssl.py:1234, in SSLSocket.recv(self, buflen, flags)
#    1230     if flags != 0:
#    1231         raise ValueError(
#    1232             "non-zero flags not allowed in calls to recv() on %s" %
#    1233             self.__class__)
# -> 1234     return self.read(buflen)
#    1235 else:
#    1236     return super().recv(buflen, flags)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\ssl.py:1107, in SSLSocket.read(self, len, buffer)
#    1105         return self._sslobj.read(len, buffer)
#    1106     else:
# -> 1107         return self._sslobj.read(len)
#    1108 except SSLError as x:
#    1109     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# 키워드 생성 제외 버전
processed_docs = []

for doc in split_docs:

    processed_docs.append(
        Document(
            page_content=doc.page_content,
            metadata=doc.metadata
        )
    )

# %% [markdown]
# ### 4. 벡터 저장

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
import shutil
import os

# 문서 중복 제거
if os.path.exists("./company_chroma_db_002"):
    shutil.rmtree("./company_chroma_db_002", ignore_errors=True)


embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

vector_store = Chroma.from_documents(
    documents=processed_docs,
    embedding=embeddings,

    collection_name="company_docs_v3",

    persist_directory="./company_chroma_db_002"
)

# %%
print(vector_store._collection.count())
# Out:
# 209

# %%
print(len(processed_docs))
# Out:
# 209

# %%
# vector_store.delete_collection()

# %% [markdown]
# ### LLM

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0.1,
    top_p=0.9
)

# %% [markdown]
# ### 5. 검색
#
# - MMR 검색 : 관련성 및 다양성 확보

# %%
retriever = vector_store.as_retriever(
    search_type="mmr",

    search_kwargs={
        "k": 3,
        "fetch_k": 10,
        "lambda_mult": 0.5
        #,"filter": {"keyword": ""}
    }
)

# %% [markdown]
# ### 6. 응답 품질 향상

# %%
def evaluate_answer(answer):

    prompt = """
    다음 답변 품질 평가

    PASS
    FAIL

    만 반환
    """

    quality = llm.invoke(
        prompt + answer
    )

    return quality.content
    print(quality.content)

# %% [markdown]
# ### 7. 챗봇 함수
#
# - 사용자 경험 개선

# %%
def chat(message, history):

    recent_history = history[-5:]

    docs = retriever.invoke(message)

    context = "\n\n".join([
        doc.page_content
        for doc in docs
    ])

    prompt = f"""
    당신은 회사 문서 QA 챗봇입니다.
    관련 내용이 없다면 추론하지 말고 없다고 답변하세요.

    최근 대화
    {recent_history}

    참고문서
    {context}

    질문
    {message}
    """

    answer = llm.invoke(prompt).content

    result = evaluate_answer(answer)

    if "FAIL" in result:
        answer = "관련 정보를 찾을 수 없습니다."


    # 출처 추출
    sources = []

    for doc in docs:
        source = doc.metadata.get("source")

        if source:
            sources.append(os.path.basename(source))

    sources = list(set(sources))

    answer += "\n\n---\n📄 참고 문서\n"
    answer += "\n".join(sources)

    return answer

# %% [markdown]
# ### 8. Gradio

# %%
import gradio as gr

with gr.Blocks(theme=gr.themes.Soft()) as demo:

    gr.Markdown("""
    # 회사 문서 QA 챗봇

    사내 PDF 및 Excel 문서를 기반으로 답변합니다.
    
    - 최근 대화 이력 반영
    - RAG 기반 문서 검색
    - 답변 품질 검증
    """)

    gr.ChatInterface(
        fn=chat,
        examples=[
            ["ERP 승인 절차 알려줘"],
            ["인사평가 기준은 무엇인가요?"],
            ["예산 편성 기준 알려줘"]
        ],
        title=None
    )

    # 파일 자동 업로드 - 추후 구현해보기
    # upload_btn = gr.Button("문서 추가")

    # upload_result = gr.Textbox()

    # upload_btn.click(
    #     upload_file,
    #     inputs=file_input,
    #     outputs=upload_result
    # )



demo.launch()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7156\918435023.py:3: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as demo:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 디벨롭

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# =========================================================
# 1. 세션 생성 (로그인 상태 유지용)
# =========================================================
# requests.Session()을 사용하면 쿠키/헤더를 유지한 상태로
# 여러 API 호출을 연속적으로 수행할 수 있음 (로그인 유지 효과)
session = requests.Session()

# =========================================================
# 2. 인증 정보 (쿠키 설정)
# =========================================================
# 사내 그룹웨어 로그인 세션을 유지하기 위한 쿠키 값
# SESSION / SCOUTER 값으로 사용자 인증 상태 유지
session.cookies.update({
    "SESSION": "ZjkwMWFlNWUtZGM2NS00MDE3LWI3YWUtMGU0YTNhZTUxMDhl",
    "SCOUTER": "x6pvk0mbgkjsb4",
    "lang": "ko",
    "locale": "ko"
})

# =========================================================
# 3. 공통 HTTP 헤더 설정
# =========================================================
# Ajax 요청으로 인식시키기 위한 헤더 설정
# Referer: 실제 그룹웨어 페이지 출처 정보
session.headers.update({
    "naonajax": "json",
    "X-Requested-With": "XMLHttpRequest",
    "Referer": "https://gw.hyvision.co.kr/ekp/main/home/homGwMain"
})

# =========================================================
# 4. API 기본 URL 정의
# =========================================================
BASE_URL = "https://gw.hyvision.co.kr/ekp"


# =========================================================
# 5. 게시글 목록 조회 API
# =========================================================
def get_article_list(session, brd_id, page=1):

    # 특정 게시판(brd_id)의 게시글 리스트 조회 payload
    payload = {
        "param": {
            "brdId": brd_id,
            "counting": "Y"   # 전체 개수 포함 여부
        },
        "paging": {
            "pageNo": page    # 페이지 번호
        }
    }

    # POST 요청으로 게시글 목록 조회
    r = session.post(
        BASE_URL + "/service/board/article/selectArticleList",
        json=payload
    )

    # HTTP 오류 발생 시 예외 처리
    r.raise_for_status()

    # JSON 형태 결과 반환
    return r.json()


# =========================================================
# 6. 게시글 상세 조회 API
# =========================================================
def get_article_view(session, brd_id, atcl_id):

    # 특정 게시글 상세 정보 요청 payload
    payload = [
        {
            "article": {
                "atclId": atcl_id,   # 게시글 ID
                "brdId": brd_id,     # 게시판 ID
                "pwd": None,         # 비밀번호 (비공개 글 대응)
                "anntmtyYn": "N"     # 익명 여부
            }
        }
    ]

    # 상세 조회 API 호출
    r = session.post(
        BASE_URL + "/service/board/article/selectArticleView",
        json=payload
    )

    r.raise_for_status()

    # 리스트 구조로 반환되므로 그대로 리턴
    return r.json()


# =========================================================
# 7. 게시판 목록 조회 API
# =========================================================
def get_board_list(session):

    # 전체 게시판 트리 구조 조회
    r = session.get(
        BASE_URL + "/service/board/selectBoardTree",
        params={
            "fldId": "BFCC300240816",  # 그룹웨어 폴더 ID
            "extnIncYn": "Y",          # 확장 포함 여부
            "bbnIncYn": "N"            # 하위 게시판 포함 여부
        }
    )

    r.raise_for_status()

    return r.json()


# =========================================================
# 8. 특정 게시판 전체 글 수집 (페이지 처리 포함)
# =========================================================
def get_all_articles(session, brd_id):

    # 1페이지 먼저 조회
    result = get_article_list(session, brd_id, 1)

    # 전체 페이지 수 확인
    total_page = result["paging"]["totalPageCnt"]

    # 첫 페이지 데이터 저장
    articles = result["atclList"]

    print(f"1 / {total_page}")

    # 2페이지 ~ 마지막 페이지까지 반복 수집
    for page in range(2, total_page + 1):

        result = get_article_list(session, brd_id, page)

        print(f"{page} / {total_page}")

        articles.extend(result["atclList"])

    return articles


# =========================================================
# 9. 전체 게시판 목록 조회
# =========================================================
boards = get_board_list(session)

print(type(boards))  # list 확인
print(len(boards))   # 게시판 개수

# 일부 구조 확인 (디버깅용)
print(json.dumps(
    boards[:3],
    ensure_ascii=False,
    indent=4
))


# =========================================================
# 10. 모든 게시판에서 게시글 수집
# =========================================================
articles = []

for board in boards:

    brd_id = board["key"]      # 게시판 ID
    board_name = board["title"]  # 게시판 이름

    print("=" * 80)
    print(f"게시판 수집 시작 : {board_name} ({brd_id})")

    try:
        # 게시판별 전체 글 수집
        board_articles = get_all_articles(session, brd_id)

        print(f" → {len(board_articles)}건")

        articles.extend(board_articles)

    except Exception as e:
        # 특정 게시판 실패 시에도 전체는 계속 진행
        print(f"{brd_id} 실패")
        print(e)


print("=" * 80)
print("전체 수집 :", len(articles))


# =========================================================
# 11. 중복 제거 (게시글 ID 기준)
# =========================================================
unique_articles = {}

for article in articles:
    # 동일 atclId 기준으로 덮어쓰기 → 중복 제거
    unique_articles[article["atclId"]] = article

articles = list(unique_articles.values())

print(len(articles))


# =========================================================
# 12. 게시글 상세 내용 수집
# =========================================================
all_docs = []

for i, article in enumerate(articles, 1):

    # 상세 API 호출
    detail = get_article_view(
        session,
        article["brdId"],
        article["atclId"]
    )[0]["article"]

    # 필요한 필드만 구조화하여 저장
    all_docs.append({
        "id": detail["atclId"],
        "board": article["brdName"],
        "title": detail["subject"],
        "writer": detail["regEmpName"],
        "date": detail["regDt"],
        "content": detail["atclCn"]
    })

    print(f"{i}/{len(articles)} 완료")


# =========================================================
# 13. HTML → Text 변환
# =========================================================
def html_to_text(html):

    # HTML 태그 제거용 파서
    soup = BeautifulSoup(html, "html.parser")

    # 줄바꿈 유지하면서 텍스트 추출
    return soup.get_text("\n", strip=True)


# 모든 문서에 대해 본문 정제
for doc in all_docs:
    doc["content"] = html_to_text(doc["content"])


# =========================================================
# 14. CSV 저장
# =========================================================
df = pd.DataFrame(all_docs)

df.to_csv(
    "companyboard.csv",
    index=False,
    encoding="utf-8-sig"
)
# Out:
# <class 'list'>
# 13
# [
#     {
#         "key": "BBNC300240816",
#         "title": "전사공지사항",
#         "nodeName": "전사공지사항",
#         "nodeType": "B",
#         "info": "NNNTNN",
#         "extn": 0,
#         "select": false,
#         "addClass": "tico_f2",
#         "children": null,
#         "isFolder": false,
#         "iconUrl": "f2",
#         "withInDay": "N",
#         "hotLineYn": "N",
#         "childBoardYn": "N",
#         "childFolderYn": "N",
#         "isLazy": false
#     },
#     {
#         "key": "BB10400001",
#         "title": "회사규정",
#         "nodeName": "회사규정",
#         "nodeType": "B",
#         "info": "NNNTNN",
#         "extn": 0,
#         "select": false,
#         "addClass": "tico_f2",
#         "children": null,
#         "isFolder": false,
#         "iconUrl": "f2",
#         "withInDay": "N",
#         "hotLineYn": "N",
#         "childBoardYn": "N",
#         "childFolderYn": "N",
#         "isLazy": false
#     },
#     {
#         "key": "BB43264178642969313655",
#         "title": "인사발령",
#         "nodeName": "인사발령",
#         "nodeType": "B",
#         "info": "NNNTNN",
#         "extn": 0,
#         "select": false,
#         "addClass": "tico_f2",
#         "children": null,
#         "isFolder": false,
#         "iconUrl": "f2",
#         "withInDay": "N",
#         "hotLineYn": "N",
#         "childBoardYn": "N",
#         "childFolderYn": "N",
#         "isLazy": false
#     }
# ]
# ================================================================================
# 게시판 수집 시작 : 전사공지사항 (BBNC300240816)
# 1 / 5
# 2 / 5
# 3 / 5
# 4 / 5
# 5 / 5
#  → 79건
# ================================================================================
# 게시판 수집 시작 : 회사규정 (BB10400001)
# 1 / 3
# 2 / 3
# 3 / 3
#  → 45건
# ================================================================================
# 게시판 수집 시작 : 인사발령 (BB43264178642969313655)
# 1 / 2
# 2 / 2
#  → 20건
# ================================================================================
# 게시판 수집 시작 : 혁신 아이디어 (BB116129123779955056892)
# 1 / 1
#  → 5건
# ================================================================================
# 게시판 수집 시작 : 경영지원 (BB99000024)
# 1 / 3
# 2 / 3
# 3 / 3
#  → 35건
# ================================================================================
# 게시판 수집 시작 : 전산지원 (BB99000050)
# 1 / 4
# 2 / 4
# 3 / 4
# 4 / 4
#  → 61건
# ================================================================================
# 게시판 수집 시작 : 결재라인 (BB99000005)
# 1 / 1
#  → 9건
# ================================================================================
# 게시판 수집 시작 : 경조사 (BB10500004)
# 1 / 20
# 2 / 20
# 3 / 20
# 4 / 20
# 5 / 20
# 6 / 20
# 7 / 20
# 8 / 20
# 9 / 20
# 10 / 20
# 11 / 20
# 12 / 20
# 13 / 20
# 14 / 20
# 15 / 20
# 16 / 20
# 17 / 20
# 18 / 20
# 19 / 20
# 20 / 20
#  → 333건
# ================================================================================
# 게시판 수집 시작 : 업무 프로세스 (BB99000006)
# 1 / 2
# 2 / 2
#  → 23건
# ================================================================================
# 게시판 수집 시작 : 자료실 (BB99000051)
# 1 / 1
#  → 15건
# ================================================================================
# 게시판 수집 시작 : 자유게시판 (BB10500011)
# 1 / 1
#  → 8건
# ================================================================================
# 게시판 수집 시작 : 동호회⚽🎣🏸🎲 (BB98520791060320468053)
# 1 / 2
# 2 / 2
#  → 31건
# ================================================================================
# 게시판 수집 시작 : 고충처리 (BB175341009561128904937)
# 1 / 1
#  → 1건
# ================================================================================
# 전체 수집 : 665
# 599
# 1/599 완료
# 2/599 완료
# 3/599 완료
# 4/599 완료
# 5/599 완료
# 6/599 완료
# 7/599 완료
# 8/599 완료
# 9/599 완료
# 10/599 완료
# 11/599 완료
# 12/599 완료
# 13/599 완료
# 14/599 완료
# 15/599 완료
# 16/599 완료
# 17/599 완료
# 18/599 완료
# 19/599 완료
# 20/599 완료
# 21/599 완료
# 22/599 완료
# 23/599 완료
# 24/599 완료
# 25/599 완료
# 26/599 완료
# 27/599 완료
# 28/599 완료
# 29/599 완료
# 30/599 완료
# 31/599 완료
# 32/599 완료
# 33/599 완료
# 34/599 완료
# 35/599 완료
# 36/599 완료
# 37/599 완료
# 38/599 완료
# 39/599 완료
# 40/599 완료
# 41/599 완료
# 42/599 완료
# 43/599 완료
# 44/599 완료
# 45/599 완료
# 46/599 완료
# 47/599 완료
# 48/599 완료
# 49/599 완료
# 50/599 완료
# 51/599 완료
# 52/599 완료
# 53/599 완료
# 54/599 완료
# 55/599 완료
# 56/599 완료
# 57/599 완료
# 58/599 완료
# 59/599 완료
# 60/599 완료
# 61/599 완료
# 62/599 완료
# 63/599 완료
# 64/599 완료
# 65/599 완료
# 66/599 완료
# 67/599 완료
# 68/599 완료
# 69/599 완료
# 70/599 완료
# 71/599 완료
# 72/599 완료
# 73/599 완료
# 74/599 완료
# 75/599 완료
# 76/599 완료
# 77/599 완료
# 78/599 완료
# 79/599 완료
# 80/599 완료
# 81/599 완료
# 82/599 완료
# 83/599 완료
# 84/599 완료
# 85/599 완료
# 86/599 완료
# 87/599 완료
# 88/599 완료
# 89/599 완료
# 90/599 완료
# 91/599 완료
# 92/599 완료
# 93/599 완료
# 94/599 완료
# 95/599 완료
# 96/599 완료
# 97/599 완료
# 98/599 완료
# 99/599 완료
# 100/599 완료
# 101/599 완료
# 102/599 완료
# 103/599 완료
# 104/599 완료
# 105/599 완료
# 106/599 완료
# 107/599 완료
# 108/599 완료
# 109/599 완료
# 110/599 완료
# 111/599 완료
# 112/599 완료
# 113/599 완료
# 114/599 완료
# 115/599 완료
# 116/599 완료
# 117/599 완료
# 118/599 완료
# 119/599 완료
# 120/599 완료
# 121/599 완료
# 122/599 완료
# 123/599 완료
# 124/599 완료
# 125/599 완료
# 126/599 완료
# 127/599 완료
# 128/599 완료
# 129/599 완료
# 130/599 완료
# 131/599 완료
# 132/599 완료
# 133/599 완료
# 134/599 완료
# 135/599 완료
# 136/599 완료
# 137/599 완료
# 138/599 완료
# 139/599 완료
# 140/599 완료
# 141/599 완료
# 142/599 완료
# 143/599 완료
# 144/599 완료
# 145/599 완료
# 146/599 완료
# 147/599 완료
# 148/599 완료
# 149/599 완료
# 150/599 완료
# 151/599 완료
# 152/599 완료
# 153/599 완료
# 154/599 완료
# 155/599 완료
# 156/599 완료
# 157/599 완료
# 158/599 완료
# 159/599 완료
# 160/599 완료
# 161/599 완료
# 162/599 완료
# 163/599 완료
# 164/599 완료
# 165/599 완료
# 166/599 완료
# 167/599 완료
# 168/599 완료
# 169/599 완료
# 170/599 완료
# 171/599 완료
# 172/599 완료
# 173/599 완료
# 174/599 완료
# 175/599 완료
# 176/599 완료
# 177/599 완료
# 178/599 완료
# 179/599 완료
# 180/599 완료
# 181/599 완료
# 182/599 완료
# 183/599 완료
# 184/599 완료
# 185/599 완료
# 186/599 완료
# 187/599 완료
# 188/599 완료
# 189/599 완료
# 190/599 완료
# 191/599 완료
# 192/599 완료
# 193/599 완료
# 194/599 완료
# 195/599 완료
# 196/599 완료
# 197/599 완료
# 198/599 완료
# 199/599 완료
# 200/599 완료
# 201/599 완료
# 202/599 완료
# 203/599 완료
# 204/599 완료
# 205/599 완료
# 206/599 완료
# 207/599 완료
# 208/599 완료
# 209/599 완료
# 210/599 완료
# 211/599 완료
# 212/599 완료
# 213/599 완료
# 214/599 완료
# 215/599 완료
# 216/599 완료
# 217/599 완료
# 218/599 완료
# 219/599 완료
# 220/599 완료
# 221/599 완료
# 222/599 완료
# 223/599 완료
# 224/599 완료
# 225/599 완료
# 226/599 완료
# 227/599 완료
# 228/599 완료
# 229/599 완료
# 230/599 완료
# 231/599 완료
# 232/599 완료
# 233/599 완료
# 234/599 완료
# 235/599 완료
# 236/599 완료
# 237/599 완료
# 238/599 완료
# 239/599 완료
# 240/599 완료
# 241/599 완료
# 242/599 완료
# 243/599 완료
# 244/599 완료
# 245/599 완료
# 246/599 완료
# 247/599 완료
# 248/599 완료
# 249/599 완료
# 250/599 완료
# 251/599 완료
# 252/599 완료
# 253/599 완료
# 254/599 완료
# 255/599 완료
# 256/599 완료
# 257/599 완료
# 258/599 완료
# 259/599 완료
# 260/599 완료
# 261/599 완료
# 262/599 완료
# 263/599 완료
# 264/599 완료
# 265/599 완료
# 266/599 완료
# 267/599 완료
# 268/599 완료
# 269/599 완료
# 270/599 완료
# 271/599 완료
# 272/599 완료
# 273/599 완료
# 274/599 완료
# 275/599 완료
# 276/599 완료
# 277/599 완료
# 278/599 완료
# 279/599 완료
# 280/599 완료
# 281/599 완료
# 282/599 완료
# 283/599 완료
# 284/599 완료
# 285/599 완료
# 286/599 완료
# 287/599 완료
# 288/599 완료
# 289/599 완료
# 290/599 완료
# 291/599 완료
# 292/599 완료
# 293/599 완료
# 294/599 완료
# 295/599 완료
# 296/599 완료
# 297/599 완료
# 298/599 완료
# 299/599 완료
# 300/599 완료
# 301/599 완료
# 302/599 완료
# 303/599 완료
# 304/599 완료
# 305/599 완료
# 306/599 완료
# 307/599 완료
# 308/599 완료
# 309/599 완료
# 310/599 완료
# 311/599 완료
# 312/599 완료
# 313/599 완료
# 314/599 완료
# 315/599 완료
# 316/599 완료
# 317/599 완료
# 318/599 완료
# 319/599 완료
# 320/599 완료
# 321/599 완료
# 322/599 완료
# 323/599 완료
# 324/599 완료
# 325/599 완료
# 326/599 완료
# 327/599 완료
# 328/599 완료
# 329/599 완료
# 330/599 완료
# 331/599 완료
# 332/599 완료
# 333/599 완료
# 334/599 완료
# 335/599 완료
# 336/599 완료
# 337/599 완료
# 338/599 완료
# 339/599 완료
# 340/599 완료
# 341/599 완료
# 342/599 완료
# 343/599 완료
# 344/599 완료
# 345/599 완료
# 346/599 완료
# 347/599 완료
# 348/599 완료
# 349/599 완료
# 350/599 완료
# 351/599 완료
# 352/599 완료
# 353/599 완료
# 354/599 완료
# 355/599 완료
# 356/599 완료
# 357/599 완료
# 358/599 완료
# 359/599 완료
# 360/599 완료
# 361/599 완료
# 362/599 완료
# 363/599 완료
# 364/599 완료
# 365/599 완료
# 366/599 완료
# 367/599 완료
# 368/599 완료
# 369/599 완료
# 370/599 완료
# 371/599 완료
# 372/599 완료
# 373/599 완료
# 374/599 완료
# 375/599 완료
# 376/599 완료
# 377/599 완료
# 378/599 완료
# 379/599 완료
# 380/599 완료
# 381/599 완료
# 382/599 완료
# 383/599 완료
# 384/599 완료
# 385/599 완료
# 386/599 완료
# 387/599 완료
# 388/599 완료
# 389/599 완료
# 390/599 완료
# 391/599 완료
# 392/599 완료
# 393/599 완료
# 394/599 완료
# 395/599 완료
# 396/599 완료
# 397/599 완료
# 398/599 완료
# 399/599 완료
# 400/599 완료
# 401/599 완료
# 402/599 완료
# 403/599 완료
# 404/599 완료
# 405/599 완료
# 406/599 완료
# 407/599 완료
# 408/599 완료
# 409/599 완료
# 410/599 완료
# 411/599 완료
# 412/599 완료
# 413/599 완료
# 414/599 완료
# 415/599 완료
# 416/599 완료
# 417/599 완료
# 418/599 완료
# 419/599 완료
# 420/599 완료
# 421/599 완료
# 422/599 완료
# 423/599 완료
# 424/599 완료
# 425/599 완료
# 426/599 완료
# 427/599 완료
# 428/599 완료
# 429/599 완료
# 430/599 완료
# 431/599 완료
# 432/599 완료
# 433/599 완료
# 434/599 완료
# 435/599 완료
# 436/599 완료
# 437/599 완료
# 438/599 완료
# 439/599 완료
# 440/599 완료
# 441/599 완료
# 442/599 완료
# 443/599 완료
# 444/599 완료
# 445/599 완료
# 446/599 완료
# 447/599 완료
# 448/599 완료
# 449/599 완료
# 450/599 완료
# 451/599 완료
# 452/599 완료
# 453/599 완료
# 454/599 완료
# 455/599 완료
# 456/599 완료
# 457/599 완료
# 458/599 완료
# 459/599 완료
# 460/599 완료
# 461/599 완료
# 462/599 완료
# 463/599 완료
# 464/599 완료
# 465/599 완료
# 466/599 완료
# 467/599 완료
# 468/599 완료
# 469/599 완료
# 470/599 완료
# 471/599 완료
# 472/599 완료
# 473/599 완료
# 474/599 완료
# 475/599 완료
# 476/599 완료
# 477/599 완료
# 478/599 완료
# 479/599 완료
# 480/599 완료
# 481/599 완료
# 482/599 완료
# 483/599 완료
# 484/599 완료
# 485/599 완료
# 486/599 완료
# 487/599 완료
# 488/599 완료
# 489/599 완료
# 490/599 완료
# 491/599 완료
# 492/599 완료
# 493/599 완료
# 494/599 완료
# 495/599 완료
# 496/599 완료
# 497/599 완료
# 498/599 완료
# 499/599 완료
# 500/599 완료
# 501/599 완료
# 502/599 완료
# 503/599 완료
# 504/599 완료
# 505/599 완료
# 506/599 완료
# 507/599 완료
# 508/599 완료
# 509/599 완료
# 510/599 완료
# 511/599 완료
# 512/599 완료
# 513/599 완료
# 514/599 완료
# 515/599 완료
# 516/599 완료
# 517/599 완료
# 518/599 완료
# 519/599 완료
# 520/599 완료
# 521/599 완료
# 522/599 완료
# 523/599 완료
# 524/599 완료
# 525/599 완료
# 526/599 완료
# 527/599 완료
# 528/599 완료
# 529/599 완료
# 530/599 완료
# 531/599 완료
# 532/599 완료
# 533/599 완료
# 534/599 완료
# 535/599 완료
# 536/599 완료
# 537/599 완료
# 538/599 완료
# 539/599 완료
# 540/599 완료
# 541/599 완료
# 542/599 완료
# 543/599 완료
# 544/599 완료
# 545/599 완료
# 546/599 완료
# 547/599 완료
# 548/599 완료
# 549/599 완료
# 550/599 완료
# 551/599 완료
# 552/599 완료
# 553/599 완료
# 554/599 완료
# 555/599 완료
# 556/599 완료
# 557/599 완료
# 558/599 완료
# 559/599 완료
# 560/599 완료
# 561/599 완료
# 562/599 완료
# 563/599 완료
# 564/599 완료
# 565/599 완료
# 566/599 완료
# 567/599 완료
# 568/599 완료
# 569/599 완료
# 570/599 완료
# 571/599 완료
# 572/599 완료
# 573/599 완료
# 574/599 완료
# 575/599 완료
# 576/599 완료
# 577/599 완료
# 578/599 완료
# 579/599 완료
# 580/599 완료
# 581/599 완료
# 582/599 완료
# 583/599 완료
# 584/599 완료
# 585/599 완료
# 586/599 완료
# 587/599 완료
# 588/599 완료
# 589/599 완료
# 590/599 완료
# 591/599 완료
# 592/599 완료
# 593/599 완료
# 594/599 완료
# 595/599 완료
# 596/599 완료
# 597/599 완료
# 598/599 완료
# 599/599 완료

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

# =========================
# 1. 텍스트 청킹 설정
# =========================
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

# =========================
# 2. Document 생성 + 청킹 + 메타데이터 유지
# =========================
docs = []

for _, row in df.iterrows():

    base_metadata = {
        "id": row["id"],
        "title": row["title"],
        "board": row["board"],
        "writer": row["writer"],
        "date": row["date"]
    }

    # content chunking
    chunks = splitter.split_text(row["content"])

    for i, chunk in enumerate(chunks):

        docs.append(
            Document(
                page_content=chunk,
                metadata={
                    **base_metadata,
                    "chunk_id": i,
                    "chunk_count": len(chunks)
                }
            )
        )

# =========================
# 3. Embedding 모델
# =========================
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large"   # small → large 업그레이드 추천
)

# =========================
# 4. FAISS Vector DB 생성
# =========================
db = FAISS.from_documents(
    docs,
    embeddings
)

# =========================
# 5. 로컬 저장
# =========================
db.save_local("gw_notice_db")

print("✔ RAG DB 생성 완료")
print("총 chunk 수:", len(docs))
# Out:
# ✔ RAG DB 생성 완료
# 총 chunk 수: 589

# %%
# import shutil
# import os

# if os.path.exists("gw_notice_db"):
#     shutil.rmtree("gw_notice_db")

# %%
db = FAISS.load_local(
    "gw_notice_db",
    OpenAIEmbeddings(model="text-embedding-3-large"),
    allow_dangerous_deserialization=True
)

docs = db.similarity_search("윤리경영", k=3)

for d in docs:
    print(d.metadata)
    print(d.page_content[:200])
    print("=" * 50)
# Out:
# {'id': 'FD112', 'title': '윤리강령', 'board': '', 'writer': '최성민', 'date': '2022-01-06 10:17:20', 'chunk_id': 0, 'chunk_count': 1}
# 윤리강령(2022)
# ==================================================
# {'id': 'BD47', 'title': '사내 윤리강령 제정 및 실천구호 공모 안내', 'board': '', 'writer': '임대호', 'date': '2018-07-17 12:20:02', 'chunk_id': 1, 'chunk_count': 2}
# (수신 : 경영지원실 임대호 차장) * 복수제출 가능
# ☞ 윤리강령을 이해하고, 실천할 수 있는 참신한 아이디어로 많은 참여 부탁드립니다.
# 감사합니다.
# *
# 윤리강령 실천구호 샘플
# (
# 예시
# )
# 구 호
# 의 미
# “매너가 기업을 만든다
# !
# ”
# 기본 예의범절 강조
# “고맙습니다”
# ,
# “감사합니다”
# ,
# “사랑합니다”
# 겸손함과 따뜻함을 갖추자
# “고객”
# ,
# “감동”
# ,
# “스
# ==================================================
# {'id': 'BA243326817934928966239', 'title': '하이비젼시스템 윤리경영 문화 정착 관련 공지', 'board': '', 'writer': '최남규', 'date': '2026-05-28 09:55:15', 'chunk_id': 0, 'chunk_count': 1}
# 안녕하십니까
# 하이비젼시스템
# 청렴한
# 윤리경영
# 문화
# 정착을
# 위하여
# 평소에도
# 금품
# 수수나
# 향응
# ·
# 접대
# 등의
# 비윤리
# 행위를
# 일체
# 금지하고
# 있습니다
# .
# 거래처에서
# 회사로
# 배송하는
# 공개적이며
# 대표성격의
# 경우를
# 제외하고
# 임직원
# 개인
# 자택에서
# 선물
# (
# 상품권
# 등
# )
# 을
# 수수할
# 경우
# 회사
# 규정에
# 따라
# 불이익
# 을
# 받을
# 수
# 있으니
# 이점
# 유의하여
# 주시기
# 바랍니다
# .
# 경영의
# 기
# ==================================================

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0.1
)

def add_context(doc):
    prompt = f"""
다음은 사내 공지 일부이다.

이 내용이 어떤 상황/주제의 문서인지 한 줄로 설명해라.
검색 최적화를 위해 키워드 중심으로 작성해라.

본문:
{doc.page_content}
"""

    res = llm.invoke(prompt).content

    doc.page_content = f"[컨텍스트]\n{res}\n\n[본문]\n{doc.page_content}"
    return doc


# 전체 문서에 컨텍스트 추가
docs_with_context = []

for i, d in enumerate(docs):
    docs_with_context.append(add_context(d))

print("컨텍스트 생성 완료:", len(docs_with_context))
# Out:
# 컨텍스트 생성 완료: 5

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

db_context = FAISS.from_documents(
    docs_with_context,
    embeddings
)

db_context.save_local("gw_context_db")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model='gpt-4.1-mini',      # 사용할 모델
    temperature=0.1,            # 낮은 값: 일관된 답변 (0.0~2.0)
    top_p=0.9,                  # 토큰 샘플링 확률 임계값 (0.0~1.0)
)

def ask(question):

    docs = retriever.invoke(question)

    context = ""

    for doc in docs:
        context += f"""
    게시판 : {doc.metadata['board']}
    제목 : {doc.metadata['title']}
    작성일 : {doc.metadata['date']}
    작성자 : {doc.metadata['writer']}

    본문
    {doc.page_content}

    ====================================================
    """

    prompt = f"""
    너는 회사 그룹웨어 공지 검색 비서이다.

    아래 공지만 근거로 답변한다.
    근거가 없으면 모른다고 답한다.
    답변할 때는 어떤 공지를 참고했는지 제목도 함께 알려준다.

    {context}

    질문
    {question}
    """

    return llm.invoke(prompt).content


print(ask("HyEdu 교육 공지 알려줘"))
# Out:
# HyEdu 교육 관련 공지는 다음과 같습니다.
#
# 1. [사내교육] 하이에듀 교육 사이트 고도화 및 강의 수강 안내 (2025-08-12)
# - 하이에듀 사이트가 새롭게 고도화되었으며, ERP/그룹웨어 계정으로 로그인 가능합니다.
# - 3D 웹 매뉴얼, 강의 콘텐츠 강화, LMS 기능 개선 등이 주요 업데이트 내용입니다.
# - 접속 경로: https://hyedu.hyvision.co.kr/
#
# 2. [사내교육] 하이비젼시스템 교육 사이트 <HyEdu> 강의 업데이트 안내 (2025-02-11)
# - 신규 강의 업데이트 소식 안내
# - 로그인 후 사이트 접속하여 강의 수강 가능
#
# 3. [사내교육] 하이에듀 신규 강의 업로드 안내 (2025-09-29)
# - Infragistics & Microsoft 초청 세미나 강의가 하이에듀에 업로드됨
# - 접속 경로 및 계정 정보 동일
# - 수강 경로: 메뉴 → 교육 과정 → 정규 과정 → 소프트웨어 → Blazor & App Builder
# - 세미나 주제 및 상세 내용 포함
#
# 참고한 공지:
# - [사내교육] 하이에듀 교육 사이트 고도화 및 강의 수강 안내
# - [사내교육] 하이비젼시스템 교육 사이트 <HyEdu> 강의 업데이트 안내
# - [사내교육] 하이에듀 신규 강의 업로드 안내

# %%
import gradio as gr

def chatbot(message, history):
    answer = ask(message)
    return answer

demo = gr.ChatInterface(
    fn=chatbot,
    title="📄 사내 그룹웨어 공지 AI",
    description="사내 공지사항을 검색해서 답변합니다."
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
boards = [
    {"id": "BBNC300240816", "name": "전사공지사항"},
    {"id": "BB10400001", "name": "회사규정"},
    {"id": "BB43264178642969313655", "name": "인사발령"},
    {"id": "BB116129123779955056892", "name": "혁신 아이디어"},
    {"id": "BB99000024", "name": "경영지원"},
    {"id": "BB99000050", "name": "전산지원"},
    {"id": "BB99000005", "name": "결재라인"},
    {"id": "BB10500004", "name": "경조사"},
    {"id": "BB99000006", "name": "업무 프로세스"},
    {"id": "BB99000051", "name": "자료실"},
    {"id": "BB10500011", "name": "자유게시판"},
    {"id": "BB98520791060320468053", "name": "동호회"},
    {"id": "BB175341009561128904937", "name": "고충처리"},
]
